# %%
import cv2
import sys, os, time
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Test

# %%
imageFile = '/Users/markus/Work/data/imdb_crop/00/nm0000100_rm1001569280_1955-1-6_2011.jpg'
cascFile ="/Users/markus/Work/Insight-AI-Project/preprocess/FaceDetect/haarcascade_frontalface_default.xml"
#cascFile ="/Users/markus/Work/Insight-AI-Project/preprocess/haarcascade_frontalface_eye.xml"

# %%
# test
faceCascade = cv2.CascadeClassifier(cascFile)
image = cv2.imread(imageFile)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)

# %% [markdown]
# ### Functions

# %%
# Create the haar cascade
faceCascade = cv2.CascadeClassifier(cascFile)


def detectFaces(imageFile,faceCascade):
    # Read the image
    image = cv2.imread(imageFile)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Detect faces in the image
    faces = faceCascade.detectMultiScale(
        gray,
        scaleFactor=1.1,
        minNeighbors=5,
        minSize=(30, 30),
        flags=cv2.CASCADE_SCALE_IMAGE
        # flags = cv2.cv.CV_HAAR_SCALE_IMAGE
        
    )
    #faces = faceCascade.detectMultiScale(gray, 1.3, 5)
    return faces

# %%
faces = detectFaces(imageFile,faceCascade)
print("Found {0} faces!".format(len(faces)))
# Out:
# Found 0 faces!

# %% [markdown]
# ### Check list of images

# %%
imagePath = "/Users/markus/Work/data/imdb_crop/00/"
imageList=os.listdir(imagePath)
nima = len(imageList)
print("Found {} images".format(nima))

ct = time.time()
numFaces=np.zeros(nima)

for k in xrange(100):#nima):
    faces = detectFaces(imagePath+imageList[k],faceCascade)
    numFaces[k] = len(faces)

print("Time = {}".format(time.time()-ct))
# Out:
# Found 3862 images
# Time = 4.35402989388

# %%
numFaces[:9]
# Out:
# array([ 0.,  2.,  1.,  0.,  1.,  0.,  1.,  0.,  1.])

# %%
faces = detectFaces(imagePath+imageList[6],faceCascade)

# %%
len(faces)
# Out:
# 1

# %%
image = cv2.imread(imagePath+imageList[6],)
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)\

# %%
plt.imshow(image)

# %%
x,y,w,h = faces[0][0], faces[0][1], faces[0][2], faces[0][3]
print(w,h)
cropped = image[y:y+h,x:x+w]

plt.imshow(cropped)
# Out:
# (71, 71)

# %%
cropped.shape
# Out:
# (60, 60, 3)

# %%
imaLi
# Out:
# array([[ 71, 132,  60,  60]], dtype=int32)
